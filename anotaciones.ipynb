# %% [markdown]
# # etapa 1 listo
# # etapa 2 listo (replicar varias veces)
# # etapa 3: agregar mas casos, mejores tecnisismos
# # etapa 4: sacar mejores conclusiones propias (no IA)
#
# buscar mas opciones
# entender el codigo de manera mas didactica
